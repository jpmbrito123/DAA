# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import sklearn as skl
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import preprocessing
from sklearn.model_selection import train_test_split

from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score
from sklearn.utils import resample
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.linear_model import LogisticRegression
import time

# %%
A_train= pd.read_csv('A_train.csv')
A_test=pd.read_csv('A_test.csv')
B_test=pd.read_csv('B_test.csv')
B_train=pd.read_csv('B_train.csv')

# %%
starttime= time.process_time()

logmodel1 = LogisticRegression(random_state=25112002,solver='newton-cg',max_iter=1000)
print(logmodel1)
logmodel1.fit(A_train,np.ravel(B_train))

endtime= time.process_time()
print(f"Time spent: {endtime-starttime} seconds")
predictions1= logmodel1.predict(A_test)
# Out:
# LogisticRegression(max_iter=1000, random_state=13122001, solver='newton-cg')
# Time spent: 0.859375 seconds

# %%
starttime= time.process_time()

logmodel2 = LogisticRegression(random_state=25112002,solver='lbfgs',max_iter=1000)
print(logmodel2)
logmodel2.fit(A_train,np.ravel(B_train))

endtime= time.process_time()
print(f"Time spent: {endtime-starttime} seconds")
predictions2= logmodel2.predict(A_test)
# Out:
# LogisticRegression(max_iter=1000, random_state=25112002)
# Time spent: 0.265625 seconds

# %%
starttime= time.process_time()

logmodel3 = LogisticRegression(random_state=25112002,solver='liblinear',max_iter=1000)
print(logmodel3)
logmodel3.fit(A_train,np.ravel(B_train))

endtime= time.process_time()
print(f"Time spent: {endtime-starttime} seconds")
predictions3= logmodel3.predict(A_test)
# Out:
# LogisticRegression(max_iter=1000, random_state=25112002, solver='liblinear')
# Time spent: 0.078125 seconds

# %%
print("With 'newton-cg': \n",classification_report(B_test,predictions1))
print("With 'lbfgs': \n",classification_report(B_test,predictions2))
print("With 'liblinear': \n",classification_report(B_test,predictions3))
# Out:
# With 'newton-cg':
#                precision    recall  f1-score   support
#
#          0.0       0.74      0.70      0.72      9233
#          1.0       0.74      0.77      0.75      9973
#
#     accuracy                           0.74     19206
#    macro avg       0.74      0.74      0.74     19206
# weighted avg       0.74      0.74      0.74     19206
#
# With 'lbfgs':
#                precision    recall  f1-score   support
#
#          0.0       0.74      0.70      0.72      9233
#          1.0       0.74      0.77      0.75      9973
#
#     accuracy                           0.74     19206
#    macro avg       0.74      0.74      0.74     19206
# weighted avg       0.74      0.74      0.74     19206
#
# With 'liblinear':
#                precision    recall  f1-score   support
#
#          0.0       0.74      0.70      0.72      9233
#          1.0       0.74      0.77      0.75      9973
#
#     accuracy                           0.74     19206
# ...

# %%
ConfusionMatrixDisplay.from_predictions(B_test, predictions1)
ConfusionMatrixDisplay.from_predictions(B_test, predictions1)
ConfusionMatrixDisplay.from_predictions(B_test, predictions3)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
